# %% [markdown]
# ## <span style="color:brown">READING  AND  UNDERSTANDING  DATASET </span>

# %%
#Ignoring warnings

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
#Importing required libraries

import numpy as np
import pandas as pd

#For visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing dataset

BIKE =  pd.read_csv("day.csv")
BIKE.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
BIKE.shape
# Out:
# (730, 16)

# %%
BIKE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# * There's only 1 object datatype other than that they're all int and float datatypes.

# %%
BIKE.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %% [markdown]
# ###  <span style="color:brown">DATA QUALITY CHECKING </span>

# %%
#percentage of missing values in columns
round(100*(BIKE.isnull().sum()/len(BIKE)), 2).sort_values(ascending=False)
# Out:
# cnt           0.0
# registered    0.0
# casual        0.0
# windspeed     0.0
# hum           0.0
# atemp         0.0
# temp          0.0
# weathersit    0.0
# workingday    0.0
# weekday       0.0
# holiday       0.0
# mnth          0.0
# yr            0.0
# season        0.0
# dteday        0.0
# instant       0.0
# dtype: float64

# %% [markdown]
# * There isn't any missing values in each columns.

# %%
#percentage of missing values in rows
round((BIKE.isnull().sum(axis=1)/len(BIKE))*100,2).sort_values(ascending=False)
# Out:
# 729    0.0
# 250    0.0
# 248    0.0
# 247    0.0
# 246    0.0
#       ...
# 484    0.0
# 483    0.0
# 482    0.0
# 481    0.0
# 0      0.0
# Length: 730, dtype: float64

# %% [markdown]
# * There isn't any missing values in row_wise

# %%
#checking duplicate values


BIKE_DUP = BIKE[BIKE.duplicated()]
print("Number of duplicate rows: ", BIKE_DUP.shape)
# Out:
# Number of duplicate rows:  (0, 16)

# %% [markdown]
# __INSIGHTS:__
#
#     As We see that rows containing zero duplicate values.
#     Hence,we can conclude that there's no duplicate values.

# %% [markdown]
# ###  <span style="color:brown">DATA CLEANING</span>

# %%
#Create a copy of the  dataframe, without the 'instant' column, 

#as this will have unique values, and donot make sense to do a value count on it.

BIKE_DUM = BIKE.iloc[:,1:16]

# %%
#Checking value_counts() for rows and columns in the entire dataframe.
#This will help to identify any Unknown/Junk values present in the dataset.
    
for col in BIKE_DUM:
    print(BIKE_DUM[col].value_counts(ascending=False), '\n\n\n')
# Out:
# 14-07-2018    1
# 16-10-2019    1
# 20-08-2018    1
# 29-06-2018    1
# 02-10-2018    1
#              ..
# 21-07-2019    1
# 28-04-2019    1
# 26-08-2019    1
# 27-06-2019    1
# 02-08-2018    1
# Name: dteday, Length: 730, dtype: int64
#
#
#
# 3    188
# 2    184
# 1    180
# 4    178
# Name: season, dtype: int64
#
#
#
# 1    365
# 0    365
# Name: yr, dtype: int64
#
#
#
# 12    62
# 10    62
# 8     62
# 7     62
# 5     62
# 3     62
# 1     62
# 11    60
# 9     60
# 6     60
# 4     60
# 2     56
# Name: mnth, dtype: int64
#
#
#
# 0    709
# 1     21
# Name: holiday, dtype: int64
#
#
#
# 2    105
# 1    105
# 6    104
# 5    104
# 4    104
# 3    104
# 0    104
# Name: weekday, dtype: int64
#
#
#
# 1    504
# 0    226
# Name: workingday, dtype: int64
#
#
#
# 1    463
# 2    246
# 3     21
# Name: weathersit, dtype: int64
#
#
#
# 10.899153    5
# 26.035000    5
# 23.130847    4
# 28.563347    4
# 27.880000    4
#             ..
# 27.025847    1
# 19.270000    1
# 13.191299    1
# ...

# %% [markdown]
# __INSIGHTS__
#
#     There seems to be no Junk/Unknown values in the entire dataset.

# %% [markdown]
# ## <span style="color:brown"> DATA PREPARATION </span>

# %% [markdown]
# ###  <span style="color:brown">REMOVING REDUNDANT AND UNWANTED COLUMN</span>

# %% [markdown]
#
#  * We just getting relevant columns into considerations by inserting it into the new dataframe.
#
#  * Here are some columns we're droping it.
#    * __instant__ has only the record index.
#    * __dteday__ has dates which is not required for this analysis.
#    * __casual__ and __registered__ both datas are in __cnt__ variable so we're dropping it.
#
#
#  * keeping the __yr__ column since,these bike-sharing systems are slowly gaining popularity, the demand for these bikes is increasing every year proving that the column  might be a good variable for prediction.

# %%
BIKE.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
BIKE_NEW = BIKE[['season', 'yr', 'mnth', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'cnt']]
BIKE_NEW.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        1           1           2  14.110847
# 1       1   0     1        0        2           1           2  14.902598
# 2       1   0     1        0        3           1           1   8.050924
# 3       1   0     1        0        4           1           1   8.200000
# 4       1   0     1        0        5           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %% [markdown]
# ###  <span style="color:brown">CREATING DUMMY VARIABLES</span>

# %% [markdown]
# * We will create dummy variables for 4 categorical variables __'mnth', 'weekday', 'season' & 'weathersit'__.
#
# * Before creating dummy variables, we will have to convert them into __'category'__ data types.

# %%
# Convert to 'category' data type
BIKE_NEW['mnth']=BIKE_NEW['mnth'].astype('category')

BIKE_NEW['Weekday']=BIKE_NEW['weekday'].astype('category')

BIKE_NEW['season']=BIKE_NEW['season'].astype('category')

BIKE_NEW['Weathersit']=BIKE_NEW['weathersit'].astype('category')

# %%
BIKE_NEW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
#  12  Weekday     730 non-null    category
#  13  Weathersit  730 non-null    category
# dtypes: category(4), float64(4), int64(6)
# memory usage: 61.1 KB

# %%
#creating dummy variables
BIKE_NEW = pd.get_dummies(BIKE_NEW,drop_first = True)
BIKE_NEW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   weekday       730 non-null    int64
#  3   workingday    730 non-null    int64
#  4   weathersit    730 non-null    int64
#  5   temp          730 non-null    float64
#  6   atemp         730 non-null    float64
#  7   hum           730 non-null    float64
#  8   windspeed     730 non-null    float64
#  9   cnt           730 non-null    int64
#  10  season_2      730 non-null    uint8
#  11  season_3      730 non-null    uint8
#  12  season_4      730 non-null    uint8
#  13  mnth_2        730 non-null    uint8
#  14  mnth_3        730 non-null    uint8
#  15  mnth_4        730 non-null    uint8
#  16  mnth_5        730 non-null    uint8
#  17  mnth_6        730 non-null    uint8
# ...

# %% [markdown]
# __STEPS:__
#
# * By creating dummy variables,
# * Dropping the original variable for which the dummy was created.
# * And Drop the first dummy variable for each set of dummies created.

# %%
BIKE_NEW.head()
# Out:
#    yr  holiday  weekday  workingday  weathersit       temp     atemp      hum  \
# 0   0        0        1           1           2  14.110847  18.18125  80.5833
# 1   0        0        2           1           2  14.902598  17.68695  69.6087
# 2   0        0        3           1           1   8.050924   9.47025  43.7273
# 3   0        0        4           1           1   8.200000  10.60610  59.0435
# 4   0        0        5           1           1   9.305237  11.46350  43.6957
#
#    windspeed   cnt  ...  mnth_11  mnth_12  Weekday_1  Weekday_2  Weekday_3  \
# 0  10.749882   985  ...        0        0          1          0          0
# 1  16.652113   801  ...        0        0          0          1          0
# 2  16.636703  1349  ...        0        0          0          0          1
# 3  10.739832  1562  ...        0        0          0          0          0
# 4  12.522300  1600  ...        0        0          0          0          0
#
# ...

# %%
BIKE_NEW.shape
# Out:
# (730, 32)

# %% [markdown]
# ## <span style="color:brown"> SPLITTING THE DATASET INTO TRAIN_SET AND TEST_SET</span>

# %% [markdown]
#    Splitting the data to Train and Test: - We will now split the data into __TRAIN__ and __TEST__ for __70:30__ ratio,
# We will use __train_test_split__ method from sklearn package for this.

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(BIKE_NEW, train_size = 0.70, test_size = 0.30, random_state = 333)

# %%
#checking shape of train and test_set 
print (df_train.shape,df_test.shape)
# Out:
# (510, 32) (219, 32)

# %%
#checking the info of train_set
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 483 to 366
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   weekday       510 non-null    int64
#  3   workingday    510 non-null    int64
#  4   weathersit    510 non-null    int64
#  5   temp          510 non-null    float64
#  6   atemp         510 non-null    float64
#  7   hum           510 non-null    float64
#  8   windspeed     510 non-null    float64
#  9   cnt           510 non-null    int64
#  10  season_2      510 non-null    uint8
#  11  season_3      510 non-null    uint8
#  12  season_4      510 non-null    uint8
#  13  mnth_2        510 non-null    uint8
#  14  mnth_3        510 non-null    uint8
#  15  mnth_4        510 non-null    uint8
#  16  mnth_5        510 non-null    uint8
#  17  mnth_6        510 non-null    uint8
# ...

# %%
#checking the info of test_set
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 22 to 313
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   weekday       219 non-null    int64
#  3   workingday    219 non-null    int64
#  4   weathersit    219 non-null    int64
#  5   temp          219 non-null    float64
#  6   atemp         219 non-null    float64
#  7   hum           219 non-null    float64
#  8   windspeed     219 non-null    float64
#  9   cnt           219 non-null    int64
#  10  season_2      219 non-null    uint8
#  11  season_3      219 non-null    uint8
#  12  season_4      219 non-null    uint8
#  13  mnth_2        219 non-null    uint8
#  14  mnth_3        219 non-null    uint8
#  15  mnth_4        219 non-null    uint8
#  16  mnth_5        219 non-null    uint8
#  17  mnth_6        219 non-null    uint8
# ...

# %% [markdown]
#  ##   <span style="color:brown">EXPLORATORY DATA ANALYSIS</span>
#
#  ###  <span style="color:brown">VISUALISING THE DATA</span>
#
# Let's now spend some time doing what is arguably the most important step - **understanding the __train and test data__**.
# - If there is some obvious multicollinearity going on, this is the first place to catch it.
# - Here's where you'll also identify if some predictors directly have a strong association with the outcome variable.

# %% [markdown]
# #### Performing EDA for __Train_Dataset__

# %%
df_train.columns
# Out:
# Index(['yr', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp',
#        'hum', 'windspeed', 'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2',
#        'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9',
#        'mnth_10', 'mnth_11', 'mnth_12', 'Weekday_1', 'Weekday_2', 'Weekday_3',
#        'Weekday_4', 'Weekday_5', 'Weekday_6', 'Weathersit_2', 'Weathersit_3'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# yr                int64
# holiday           int64
# weekday           int64
# workingday        int64
# weathersit        int64
# temp            float64
# atemp           float64
# hum             float64
# windspeed       float64
# cnt               int64
# season_2          uint8
# season_3          uint8
# season_4          uint8
# mnth_2            uint8
# mnth_3            uint8
# mnth_4            uint8
# mnth_5            uint8
# mnth_6            uint8
# mnth_7            uint8
# mnth_8            uint8
# mnth_9            uint8
# mnth_10           uint8
# mnth_11           uint8
# mnth_12           uint8
# Weekday_1         uint8
# Weekday_2         uint8
# Weekday_3         uint8
# Weekday_4         uint8
# Weekday_5         uint8
# Weekday_6         uint8
# Weathersit_2      uint8
# Weathersit_3      uint8
# dtype: object

# %% [markdown]
# __OBSERVATIONS FOR NUMERICAL VARIABLES__

# %%
# Create a new dataframe of only numeric variables:

BIKE_NUM=df_train[[ 'temp', 'atemp', 'hum', 'windspeed','cnt']]

sns.pairplot(BIKE_NUM, diag_kind= 'kde',height=1.5)
plt.show()

# %% [markdown]
# __INSIGHTS__
#
#    The above Pair-Plot tells us that there is a LINEAR RELATION between __'temp','atemp' and 'cnt'__

# %% [markdown]
# __OBSERVATIONS FOR CATEGORICAL VARIABLES__

# %%
# Build boxplot of all categorical variables (before creating dummies) againt the target variable 'cnt' 
# To see how each of the predictor variable stackup against the target variable.

plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = BIKE)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = BIKE)
plt.subplot(2,3,3)
sns.boxplot(x = 'weathersit', y = 'cnt', data = BIKE)
plt.subplot(2,3,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = BIKE)
plt.subplot(2,3,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = BIKE)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = BIKE)
plt.show()

# %% [markdown]
# There were __6 categorical variables__ in the dataset.
# We used Box plot (refer the fig above) to study their effect on the __dependent__ variable __‘cnt’__ .

# %% [markdown]
# __INSIGHTS :__
#
# * __season__: Almost 32% of the bike booking was happening in season3 with a median of over 5000 bookings (for the period of 2 years). Season2 followed this & season4 with 27% & 25% of total booking. This indicates season can be a good predictor for the dependent variable`season indicates(1:spring, 2:summer, 3:fall, 4:winter)`.
#
# * __Mnth__: Almost 10% of the bike booking was happening in the months 5,6,7,8 & 9 with a median of over 4000 booking per month. This indicates mnth has some trend for bookings and can be a good predictor for the dependent variable `mnth : month ( 1 to 12)`.
#
# * __weathersit__: Almost 67% of the bike booking was happening during ‘weathersit1 with a median of close to 5000 booking (for the period of 2 years). This was followed by weathersit2 with 30% of total booking. This indicates, weathersit does show some trend towards the bike bookings can be a good predictor for the dependent variable.
#
# * __holiday__: Almost 97.6% of the bike booking was happening when it is not a holiday, which means this data is clearly biased. This indicates, holiday CANNOT be a good predictor for the dependent variable `holiday : weather day is a holiday or not`.
#
# * __weekday__: weekday variable shows very close trend (between 13.5%-14.8% of total booking on all days of the week) having their independent medians between 4000 to 5000 bookings. This variable can have some or no influence on the predictor. I will let the model decide if this needs to be added or not.
#
# * __working day__: Almost 69% of the bike booking was happening in ‘working day’ with a median of close to 5000 booking (for the period of 2 years). This indicates, working day can be a good predictor for the dependent variable `workingday : if day is neither weekend nor holiday is 1, otherwise is 0`.

# %% [markdown]
# #### CORRELATION MATRIX

# %%
# Let's check the correlation coefficients to see which variables are highly correlated. 
# Here we are considering only those variables (dataframe: BIKE_NEW) that were chosen for analysis.

plt.figure(figsize = (25,20))
sns.heatmap(BIKE_NEW.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# __INSIGHTS:__
#
#   * The heatmap clearly shows which all variable are multicollinear in nature, and which variable have high collinearity with the target variable.
#
#   * We will refer this map back-and-forth while building the linear model so as to validate different correlated values along with VIF & p-value, for identifying the correct variable to select/eliminate from the model.

# %% [markdown]
# ## <span style="color:brown"> RESCALING THE FEATURES</span>

# %% [markdown]
# As we know, there are two common ways of rescaling.
#
# 1. Min-Max scaling
# 2. Standardisation (mean-0, sigma-1)
#
# This time, we will use MinMax scaling.

# %%
#importing min_max scaling library 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
# Checking the values before scaling
df_train.head()
# Out:
#      yr  holiday  weekday  workingday  weathersit       temp     atemp  \
# 483   1        0        1           1           1  18.791653  22.50605
# 650   1        0        0           0           1  16.126653  19.56980
# 212   0        0        3           1           1  31.638347  35.16460
# 714   1        0        1           1           2  14.862500  18.49690
# 8     0        0        2           1           1   5.671653   5.80875
#
#          hum  windspeed   cnt  ...  mnth_11  mnth_12  Weekday_1  Weekday_2  \
# 483  58.7083   7.832836  6304  ...        0        0          1          0
# 650  49.4583   9.791514  7109  ...        0        0          0          0
# 212  55.0833  10.500039  4266  ...        0        0          0          0
# 714  83.8750   6.749714  3786  ...        0        1          1          0
# 8    43.4167  24.250650   822  ...        0        0          0          1
#
#      Weekday_3  Weekday_4  Weekday_5  Weekday_6  Weathersit_2  Weathersit_3
# ...

# %%
# Apply scaler() to all the numeric variables

num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
# Checking values after scaling
df_train.head()
# Out:
#      yr  holiday  weekday  workingday  weathersit      temp     atemp  \
# 483   1        0        1           1           1  0.497426  0.487055
# 650   1        0        0           0           1  0.416433  0.409971
# 212   0        0        3           1           1  0.887856  0.819376
# 714   1        0        1           1           2  0.378013  0.381804
# 8     0        0        2           1           1  0.098690  0.048706
#
#           hum  windspeed       cnt  ...  mnth_11  mnth_12  Weekday_1  \
# 483  0.609956   0.194850  0.722734  ...        0        0          1
# 650  0.513852   0.255118  0.815347  ...        0        0          0
# 212  0.572294   0.276919  0.488265  ...        0        0          0
# 714  0.871429   0.161523  0.433042  ...        0        1          1
# 8    0.451083   0.700017  0.092039  ...        0        0          0
#
#      Weekday_2  Weekday_3  Weekday_4  Weekday_5  Weekday_6  Weathersit_2  \
# ...

# %%
df_train.describe()
# Out:
#                yr     holiday     weekday  workingday  weathersit        temp  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.501961    0.023529    2.994118    0.692157    1.392157    0.540901
# std      0.500487    0.151726    2.009302    0.462054    0.538441    0.227898
# min      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000    0.000000    1.000000    0.000000    1.000000    0.343228
# 50%      1.000000    0.000000    3.000000    1.000000    1.000000    0.540519
# 75%      1.000000    0.000000    5.000000    1.000000    2.000000    0.740406
# max      1.000000    1.000000    6.000000    1.000000    3.000000    1.000000
#
#             atemp         hum   windspeed         cnt  ...     mnth_11  \
# count  510.000000  510.000000  510.000000  510.000000  ...  510.000000
# mean     0.515631    0.647390    0.346318    0.515144  ...    0.086275
# ...

# %% [markdown]
# ##  <span style="color:brown">BUILDING  A LINEAR  MODEL</span>

# %% [markdown]
# DIVIDING __TRAIN DATA_SET__ INTO __X__ AND __Y__ FOR BUILDING MODEL

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %% [markdown]
# __RFE__ -*Recursive Feature Elimination*: We will be using the LinearRegression function from SciKit Learn for its compatibility with RFE.

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 15
lm = LinearRegression()
lm.fit(X_train, y_train)
# running RFE
rfe = RFE(lm, 15)             
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('weekday', False, 14),
#  ('workingday', False, 12),
#  ('weathersit', True, 1),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_2', True, 1),
#  ('season_3', True, 1),
#  ('season_4', True, 1),
#  ('mnth_2', False, 9),
#  ('mnth_3', True, 1),
#  ('mnth_4', False, 5),
#  ('mnth_5', False, 3),
#  ('mnth_6', False, 4),
#  ('mnth_7', False, 17),
#  ('mnth_8', False, 6),
#  ('mnth_9', True, 1),
#  ('mnth_10', True, 1),
#  ('mnth_11', False, 10),
#  ('mnth_12', False, 11),
#  ('Weekday_1', False, 7),
#  ('Weekday_2', False, 2),
#  ('Weekday_3', False, 8),
#  ('Weekday_4', False, 15),
#  ('Weekday_5', False, 16),
#  ('Weekday_6', False, 13),
#  ('Weathersit_2', True, 1),
#  ('Weathersit_3', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'season_2', 'season_3', 'season_4', 'mnth_3', 'mnth_9', 'mnth_10',
#        'Weathersit_2', 'Weathersit_3'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['weekday', 'workingday', 'mnth_2', 'mnth_4', 'mnth_5', 'mnth_6',
#        'mnth_7', 'mnth_8', 'mnth_11', 'mnth_12', 'Weekday_1', 'Weekday_2',
#        'Weekday_3', 'Weekday_4', 'Weekday_5', 'Weekday_6'],
#       dtype='object')

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %% [markdown]
# ## <span style="color:brown"> BUILDING STATS-MODEL</span>

# %% [markdown]
# ## __MODEL 1__

# %% [markdown]
# __CHECK VIF__
#
# __Variance Inflation Factor__ or __VIF__, gives a basic quantitative idea about how much the feature variables are correlated with each other. It is an extremely important parameter to test our linear model. The formula for calculating `VIF` is:
#
# ### $ VIF_i = \frac{1}{1 - {R_i}^2} $

# %% [markdown]
# __CHECK FOR THE `VIF` VALUES OF THE FEATURE VARIABLES__

# %%
#Importing stats model libraries

from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features     VIF
# 2     weathersit  108.90
# 3           temp   57.86
# 4          atemp   53.40
# 13  Weathersit_2   14.89
# 8       season_3    5.23
# 14  Weathersit_3    4.81
# 7       season_2    2.67
# 9       season_4    2.31
# 5            hum    1.94
# 12       mnth_10    1.53
# 6      windspeed    1.24
# 11        mnth_9    1.18
# 10        mnth_3    1.14
# 0             yr    1.04
# 1        holiday    1.01

# %%
#Importing stats model libraries

import statsmodels.api as sm

# Add a constant
X_train_lm1 = sm.add_constant(X_train_rfe)

# Create a first fitted model
lr1 = sm.OLS(y_train, X_train_lm1).fit()

# %%
# Check the parameters obtained

lr1.params
# Out:
# const           0.284948
# yr              0.229398
# holiday        -0.047854
# weathersit     -0.049080
# temp            0.436703
# atemp           0.054497
# hum            -0.182639
# windspeed      -0.185571
# season_2        0.129154
# season_3        0.079124
# season_4        0.151687
# mnth_3          0.046394
# mnth_9          0.100417
# mnth_10         0.055537
# Weathersit_2    0.003277
# Weathersit_3   -0.168652
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     181.7
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.03e-184
# Time:                        16:34:29   Log-Likelihood:                 501.98
# No. Observations:                 510   AIC:                            -974.0
# Df Residuals:                     495   BIC:                            -910.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2849      0.023     12.362      0.000       0.240       0.330
# ...

# %% [markdown]
# ## __MODEL 2__

# %% [markdown]
# Removing the variable 'atemp' based on its High p-value & High VIF

# %%
X_train_new = X_train_rfe.drop(["atemp"], axis = 1)

# %% [markdown]
# __VIF CHECK__

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features     VIF
# 2     weathersit  108.29
# 12  Weathersit_2   14.76
# 7       season_3    5.18
# 13  Weathersit_3    4.77
# 3           temp    3.61
# 6       season_2    2.67
# 8       season_4    2.31
# 4            hum    1.93
# 11       mnth_10    1.53
# 5      windspeed    1.20
# 10        mnth_9    1.18
# 9         mnth_3    1.14
# 0             yr    1.04
# 1        holiday    1.01

# %%
# Add a constant
X_train_lm2 = sm.add_constant(X_train_new)

# Create a first fitted model
lr2 = sm.OLS(y_train, X_train_lm2).fit()

# %%
# Check the parameters obtained

lr2.params
# Out:
# const           0.285779
# yr              0.229386
# holiday        -0.048199
# weathersit     -0.049081
# temp            0.488190
# hum            -0.182103
# windspeed      -0.187669
# season_2        0.129265
# season_3        0.078252
# season_4        0.151927
# mnth_3          0.046517
# mnth_9          0.100423
# mnth_10         0.055605
# Weathersit_2    0.003135
# Weathersit_3   -0.168997
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     196.0
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          7.80e-186
# Time:                        16:34:30   Log-Likelihood:                 501.91
# No. Observations:                 510   AIC:                            -975.8
# Df Residuals:                     496   BIC:                            -916.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2858      0.023     12.462      0.000       0.241       0.331
# ...

# %% [markdown]
# ## __MODEL 3__

# %% [markdown]
# * Removing the variable 'hum' based on its Very High 'VIF' value.
# * Even though the VIF of hum is second highest, we decided to drop 'hum' and not 'temp' based on general knowledge that temperature can be an important factor for a business like bike rentals, and wanted to retain 'temp'.

# %%
X_train_new = X_train_new.drop(["hum"], axis = 1)

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 2     weathersit  43.13
# 11  Weathersit_2   9.65
# 6       season_3   5.13
# 3           temp   3.46
# 12  Weathersit_3   3.11
# 5       season_2   2.67
# 7       season_4   2.30
# 10       mnth_10   1.53
# 9         mnth_9   1.17
# 8         mnth_3   1.13
# 4      windspeed   1.10
# 0             yr   1.02
# 1        holiday   1.01

# %%
# Add a constant
X_train_lm3 = sm.add_constant(X_train_new)

# Create a first fitted model
lr3 = sm.OLS(y_train, X_train_lm3).fit()

# %%
lr3.params
# Out:
# const           0.214651
# yr              0.233886
# holiday        -0.046841
# weathersit     -0.083868
# temp            0.454930
# windspeed      -0.148535
# season_2        0.130849
# season_3        0.087716
# season_4        0.148278
# mnth_3          0.054847
# mnth_9          0.091598
# mnth_10         0.054436
# Weathersit_2    0.007771
# Weathersit_3   -0.153145
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     201.4
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          4.40e-182
# Time:                        16:34:31   Log-Likelihood:                 490.22
# No. Observations:                 510   AIC:                            -954.4
# Df Residuals:                     497   BIC:                            -899.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2147      0.018     11.960      0.000       0.179       0.250
# ...

# %% [markdown]
# ## __MODEL 4__

# %% [markdown]
# * Removing the variable 'season3' based on its Very High 'VIF' value.
# * Even though the VIF of season3 is second highest, we decided to drop 'season3' and not 'temp' based on general knowledge that temperature can be an important factor for a business like bike rentals, and wanted to retain 'temp'.

# %%
X_train_new = X_train_new.drop(["season_3"], axis = 1)

# %% [markdown]
# __VIF CHECK__

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 2     weathersit  41.49
# 10  Weathersit_2   9.41
# 11  Weathersit_3   2.99
# 6       season_4   1.72
# 9        mnth_10   1.49
# 3           temp   1.26
# 5       season_2   1.18
# 8         mnth_9   1.13
# 7         mnth_3   1.10
# 4      windspeed   1.09
# 0             yr   1.02
# 1        holiday   1.01

# %%
# Add a constant
X_train_lm4 = sm.add_constant(X_train_new)

# Create a first fitted model
lr4 = sm.OLS(y_train, X_train_lm4).fit()

# %%
# Check the parameters obtained

lr4.params
# Out:
# const           0.200033
# yr              0.232150
# holiday        -0.050606
# weathersit     -0.083873
# temp            0.566106
# windspeed      -0.152790
# season_2        0.082717
# season_4        0.117842
# mnth_3          0.043524
# mnth_9          0.102996
# mnth_10         0.043146
# Weathersit_2    0.007520
# Weathersit_3   -0.145712
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     211.4
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.14e-179
# Time:                        16:34:31   Log-Likelihood:                 481.72
# No. Observations:                 510   AIC:                            -939.4
# Df Residuals:                     498   BIC:                            -888.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2000      0.018     11.194      0.000       0.165       0.235
# ...

# %% [markdown]
# ## __MODEL 5__

# %% [markdown]
# Removing the variable 'mnth_10' based on its Very High p-value.

# %%
X_train_new = X_train_new.drop(["mnth_10"], axis = 1)

# %% [markdown]
# __VIF CHECK__

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 2     weathersit  41.34
# 9   Weathersit_2   9.35
# 10  Weathersit_3   2.96
# 6       season_4   1.26
# 3           temp   1.23
# 5       season_2   1.18
# 7         mnth_3   1.10
# 8         mnth_9   1.10
# 4      windspeed   1.09
# 0             yr   1.02
# 1        holiday   1.01

# %%
# Add a constant
X_train_lm5 = sm.add_constant(X_train_new)

# Create a first fitted model
lr5 = sm.OLS(y_train, X_train_lm5).fit()

# %%
# Check the parameters obtained

lr5.params
# Out:
# const           0.196065
# yr              0.230954
# holiday        -0.049685
# weathersit     -0.082384
# temp            0.573550
# windspeed      -0.155703
# season_2        0.081533
# season_4        0.133332
# mnth_3          0.044245
# mnth_9          0.096454
# Weathersit_2    0.007714
# Weathersit_3   -0.143082
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     230.0
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.06e-179
# Time:                        16:34:32   Log-Likelihood:                 478.96
# No. Observations:                 510   AIC:                            -935.9
# Df Residuals:                     499   BIC:                            -889.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1961      0.018     10.974      0.000       0.161       0.231
# ...

# %% [markdown]
# ## __MODEL 6__

# %% [markdown]
# Removing the variable 'mnth_3' based on its High 'p-value'.

# %%
X_train_new = X_train_new.drop(["mnth_3"], axis = 1)

# %% [markdown]
# __CHECK VIF__

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 2    weathersit  39.50
# 8  Weathersit_2   9.11
# 9  Weathersit_3   2.91
# 6      season_4   1.21
# 5      season_2   1.18
# 3          temp   1.17
# 7        mnth_9   1.10
# 4     windspeed   1.09
# 0            yr   1.02
# 1       holiday   1.01

# %%
# Add a constant
X_train_lm6 = sm.add_constant(X_train_new)

# Create a first fitted model
lr6 = sm.OLS(y_train, X_train_lm6).fit()

# %%
# Check the parameters obtained

lr6.params
# Out:
# const           0.203601
# yr              0.231645
# holiday        -0.052434
# weathersit     -0.079570
# temp            0.561849
# windspeed      -0.154861
# season_2        0.081671
# season_4        0.127391
# mnth_9          0.094670
# Weathersit_2    0.005820
# Weathersit_3   -0.144495
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     251.7
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          2.30e-179
# Time:                        16:34:32   Log-Likelihood:                 475.31
# No. Observations:                 510   AIC:                            -930.6
# Df Residuals:                     500   BIC:                            -888.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2036      0.018     11.468      0.000       0.169       0.238
# ...

# %% [markdown]
# __INSIGHTS :__
#
#    This model looks good, as there seems to be VERY LOW Multicollinearity between the predictors and the p-values for all the predictors seems to be significant. For now, we will consider this as our final model (unless the Test data metrics are not significantly close to this number)

# %% [markdown]
# ## <span style="color:brown"> FINAL MODEL INTERPRETATION </span>

# %% [markdown]
# ###  HYPOTHESIS TESTING

# %% [markdown]
# Hypothesis testing states that:
#
# * H0:B1=B2=...=Bn=0
# * H1: at least one Bi!=0

# %% [markdown]
# ### __lr6 MODEL COEFFICIENT VALUES__

# %% [markdown]
# * const          ---  (0.2036)
# * yr             ---  (0.2316)
# * holiday        ---  (-0.0524)
# * weathersit     ---  (-0.0796)
# * temp           ---  (0.5618)
# * windspeed      ---  (-0.1549)
# * season_2       ---  (0.0817)
# * season_4       ---  (0.1274)
# * mnth_9         ---  (0.0947)
# * Weathersit_2   ---  (0.0058)
# * Weathersit_3   ---  (-0.1445)

# %% [markdown]
# __INSIGHTS__
#
#    From the __lr6 model summary__, it is evident that all our coefficients are not equal to zerowhich means We can __REJECT__ the __NULL HYPOTHESIS__.

# %% [markdown]
# ### __F Statistics__
#
# F-Statistics is used for testing the overall significance of the Model: Higher the F-Statistics, more significant the Model is
#
#   * F-statistic:  251.7
#   * Prob (F-statistic):  2.30e-179
#   * The F-Statistics value of  252 (which is greater than 1) and the p-value of '~0.0000' states that the overall model is significant.

# %% [markdown]
# ### __The equation of best fitted surface based on model lr6:__
#
#
#     cnt = 0.2036 + (yr × 0.2316) + (workingday × -0.0524) + (temp × -0.0796) − (windspeed × 0.5618) + (season2 × 0.0817) +
#        (season4 ×0.1274) + (mnth9 × 0.0947) − (weathersit2 × 0.0058) − (weathersit3 × -0.1445)

# %% [markdown]
# __Interpretation of Coefficients:__
#
#
# * __temp__: A coefficient value of ‘0.5618’ indicated that a unit increase in temp variable, increases the bike hire numbers by 0.5618 units.
#
# * __weathersit_3__: A coefficient value of ‘-0.1445’ indicated that, w.r.t Weathersit1, a unit increase in Weathersit3 variable, decreases the bike hire numbers by 0.1445 units.
#
# * __yr__: A coefficient value of '0.2316’ indicated that a unit increase in yr variable, increases the bike hire numbers by 0.2316  units.
#
# * __season_4__: A coefficient value of ‘0.1274’ indicated that w.r.t season_1, a unit increase in season_4 variable increases the bike hire numbers by 0.1274 units.
#
# * __windspeed__: A coefficient value of ‘-0.1549’ indicated that, a unit increase in windspeed variable decreases the bike hire numbers by 0.1549 units.
#
# * __workingday__: A coefficient value of ‘-0.0524’ indicated that, a unit increase in workingday variable increases the bike hire numbers by 0.0524 units.
#
# * __season_2__: A coefficient value of ‘0.0817’ indicated that w.r.t season_1, a unit increase in season_2 variable decreases the bike hire numbers by 0.0817 units.
#
# * __mnth_9__: A coefficient value of ‘0.0947’ indicated that w.r.t mnth_1, a unit increase in mnth_9 variable increases the bike hire numbers by 0.0947 units.
#
# * __weathersit_2__: A coefficient value of ‘0.0058’ indicated that, w.r.t Weathersit1, a unit increase in Weathersit2 variable, decreases the bike hire numbers by 0.0058 units.
#
# * __const__: The Constant value of ‘0.2036’ indicated that, in the absence of all other predictor variables (i.e. when x1,x2...xn =0), The bike rental can still increase by 0.2036 units.

# %% [markdown]
# ## <span style="color:brown">ASSUMPTIONS</span>

# %% [markdown]
# ### Error terms are normally distributed with mean zero (not X, Y)

# %% [markdown]
# __RESIDUAL ANALYSIS OF TRAINING DATA__

# %%
y_train_pred = lr6.predict(X_train_lm6)

# %%
res = y_train-y_train_pred
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((res), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                   
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# __INSIGHTS__:
#
#    we can see that the Residuals in histogram are normally distributed. Hence our assumption for Linear Regression is valid.

# %% [markdown]
# ### There is a linear relationship between X and Y

# %%
BIKE_NEW= BIKE_NEW[[ 'temp', 'atemp', 'hum', 'windspeed','cnt']]

sns.pairplot(BIKE_NUM, diag_kind='kde',height=1.5)
plt.show()

# %% [markdown]
# __INSIGHTS:__
#
#    Using the pair plot, we could see there is a linear relation between temp and atemp variable with the predictor ‘cnt’.

# %% [markdown]
# ### There is No Multicollinearity between the predictor variables

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 2    weathersit  39.50
# 8  Weathersit_2   9.11
# 9  Weathersit_3   2.91
# 6      season_4   1.21
# 5      season_2   1.18
# 3          temp   1.17
# 7        mnth_9   1.10
# 4     windspeed   1.09
# 0            yr   1.02
# 1       holiday   1.01

# %% [markdown]
# __INSIGHTS:__
#
# From the VIF calculation we could find that there is no multicollinearity existing between the predictor variables, as all the values are within permissible range of below 5.

# %% [markdown]
# ## <span style="color:brown">MAKING PREDICTION USING FINAL MODEL</span>

# %% [markdown]
# Now that we have fitted the model and checked the assumptions, it's time to go ahead and make predictions using the final model (lr6).

# %% [markdown]
# #### __Applying the scaling on the test sets__

# %%
# Apply scaler() to all numeric variables in test dataset. Note: we will only use scaler.transform, 
# as we want to use the metrics that the model learned from the training data to be applied on the test data. 
# In other words, we want to prevent the information leak from train to test dataset.

num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test.head()
# Out:
#      yr  holiday  weekday  workingday  weathersit      temp     atemp  \
# 22    0        0        2           1           1  0.046591  0.025950
# 468   1        0        0           0           1  0.543115  0.536771
# 553   1        0        1           1           1  0.951196  0.933712
# 504   1        0        1           1           1  0.699909  0.662746
# 353   0        0        4           1           2  0.407087  0.416610
#
#           hum  windspeed       cnt  ...  mnth_11  mnth_12  Weekday_1  \
# 22   0.453529   0.462217  0.110907  ...        0        0          0
# 468  0.522511   0.347424  0.855729  ...        0        0          0
# 553  0.596104   0.212829  0.534975  ...        0        0          1
# 504  0.551083   0.478229  0.817648  ...        0        0          1
# 353  0.618615   0.080770  0.428900  ...        0        1          0
#
#      Weekday_2  Weekday_3  Weekday_4  Weekday_5  Weekday_6  Weathersit_2  \
# ...

# %%
df_test.describe()
# Out:
#                yr     holiday     weekday  workingday  weathersit        temp  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.493151    0.041096    3.013699    0.689498    1.397260    0.551225
# std      0.501098    0.198967    1.978043    0.463759    0.560301    0.229463
# min      0.000000    0.000000    0.000000    0.000000    1.000000    0.046591
# 25%      0.000000    0.000000    1.000000    0.000000    1.000000    0.356479
# 50%      0.000000    0.000000    3.000000    1.000000    1.000000    0.557653
# 75%      1.000000    0.000000    5.000000    1.000000    2.000000    0.751309
# max      1.000000    1.000000    6.000000    1.000000    3.000000    0.984424
#
#             atemp         hum   windspeed         cnt  ...     mnth_11  \
# count  219.000000  219.000000  219.000000  219.000000  ...  219.000000
# mean     0.527528    0.662567    0.346706    0.518889  ...    0.073059
# ...

# %% [markdown]
# __Dividing into X_test and y_test__

# %%
y_test = df_test.pop('cnt')
X_test = df_test
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 22 to 313
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   weekday       219 non-null    int64
#  3   workingday    219 non-null    int64
#  4   weathersit    219 non-null    int64
#  5   temp          219 non-null    float64
#  6   atemp         219 non-null    float64
#  7   hum           219 non-null    float64
#  8   windspeed     219 non-null    float64
#  9   season_2      219 non-null    uint8
#  10  season_3      219 non-null    uint8
#  11  season_4      219 non-null    uint8
#  12  mnth_2        219 non-null    uint8
#  13  mnth_3        219 non-null    uint8
#  14  mnth_4        219 non-null    uint8
#  15  mnth_5        219 non-null    uint8
#  16  mnth_6        219 non-null    uint8
#  17  mnth_7        219 non-null    uint8
# ...

# %%
#Selecting the variables that were part of final model.
col1=X_train_new.columns
X_test=X_test[col1]

# Adding constant variable to test dataframe
X_test_lm6 = sm.add_constant(X_test)
X_test_lm6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 22 to 313
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         219 non-null    float64
#  1   yr            219 non-null    int64
#  2   holiday       219 non-null    int64
#  3   weathersit    219 non-null    int64
#  4   temp          219 non-null    float64
#  5   windspeed     219 non-null    float64
#  6   season_2      219 non-null    uint8
#  7   season_4      219 non-null    uint8
#  8   mnth_9        219 non-null    uint8
#  9   Weathersit_2  219 non-null    uint8
#  10  Weathersit_3  219 non-null    uint8
# dtypes: float64(3), int64(3), uint8(5)
# memory usage: 13.0 KB

# %%
# Making predictions using the final model (lr6)

y_pred = lr6.predict(X_test_lm6)

# %% [markdown]
# ## <span style="color:brown">MODEL EVALUATION</span>

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred, alpha=.6,color = 'blue')
fig.suptitle('y_test vs y_pred', fontsize = 20)              
plt.xlabel('y_test', fontsize = 18)                          
plt.ylabel('y_pred', fontsize = 16) 
plt.show()

# %% [markdown]
# ## <span style="color:brown">R^2 Value for TEST</span>

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
#y_test is the test data set for the target variable, and y_pred is the variable containing the predicted values of the target variable
#on the test set.
# Out:
# 0.8165687788130964

# %% [markdown]
# ## <span style="color:brown">Adjusted R^2 Value for TEST</span>

# %%
# We already have the value of R^2 (calculated in above step)

r2=0.8165687788130964

# %%
# Get the shape of X_test
X_test.shape
# Out:
# (219, 10)

# %%
# n is number of rows in X

n = X_test.shape[0]

# %%
# Number of features (predictors, p) is the shape along axis 1
p = X_test.shape[1]

# %%
# We find the Adjusted R-squared using the formula

adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
adjusted_r2
# Out:
# 0.8077499701021876

# %% [markdown]
# ## <span style="color:brown">FINAL RESULT COMPARISON</span>

# %% [markdown]
# * __Train R^2__ :0.819
# * __Train Adjusted R^2__ : 0.816
# * __Test R^2__ :0.816
# * __Test Adjusted R^2__ :0.807
#
#       This seems to be a really good model that can very well 'Generalize' various datasets.

# %% [markdown]
# #### As per our final Model, the top 3 predictor variables that influences the bike booking are:
#
#
#
# * __Temperature (temp)__ - A coefficient value of ‘0.5618’ indicated that a unit increase in temp variable increases the bike hire numbers by 0.5618 units.
#
# * __Weather Situation 3 (weathersit_3)__ - A coefficient value of‘-0.1445’indicated that, w.r.t Weathersit1, a unit increase in Weathersit3 variable decreases the bike hire numbers by 0.1445 units.
#
# * __Year (yr)__ - A coefficient value of '0.2316’  indicated that a unit increase in yr variable increases the bike hire numbers by0.2316 units.
#
#
#        So, it's suggested to consider these variables utmost importance while planning, to achieve maximum Booking.
#
#  #### The next best features that can also be considered are
#
#
# * __season_4:__ - A coefficient value of ‘0.1274’ indicated that w.r.t season_1, a unit increase in season_4 variable increases the bike hire numbers by 0.1274 units.
#
# * __wind speed:__ - A coefficient value of ‘-0.1549’ indicated that, a unit increase in wind speed variable decreases the bike hire numbers by 0.1549 units.
#
# __NOTE:__
#
#    `weathersit_1: Clear, Few clouds, Partly cloudy, Partly cloudy`
#
#   `weathersit_3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds`
#
#    `season1: spring`
#
#   `season4: winter`
